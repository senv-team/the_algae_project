# %%
# not clean, to dowload data from the url paths

# %%
# pip install landsatxplore

username = "senv_team"

password= "ketchup&Mustard1"

output_dir = '../../datasets/landsat'

# %%
if False:
    #!/usr/bin/python

    # https://urs.earthdata.nasa.gov/documentation/for_users/data_access/python

    import requests # get the requsts library from https://github.com/requests/requests



    # overriding requests.Session.rebuild_auth to mantain headers when redirected

    class SessionWithHeaderRedirection(requests.Session):

        AUTH_HOST = 'urs.earthdata.nasa.gov'

        def __init__(self, username, password):

            super().__init__()

            self.auth = (username, password)



       # Overrides from the library to keep headers when redirected to or from

       # the NASA auth host.

        def rebuild_auth(self, prepared_request, response):

            headers = prepared_request.headers

            url = prepared_request.url



            if 'Authorization' in headers:

                original_parsed = requests.utils.urlparse(response.request.url)

                redirect_parsed = requests.utils.urlparse(url)



                if (original_parsed.hostname != redirect_parsed.hostname) and redirect_parsed.hostname != self.AUTH_HOST and original_parsed.hostname != self.AUTH_HOST:
                    del headers['Authorization']



            return



    # create session with the user credentials that will be used to authenticate access to the data



    session = SessionWithHeaderRedirection(username, password)



    # the url of the file we wish to retrieve

    url = "https://n5eil01u.ecs.nsidc.org/MOST/MOD10A1.006/2016.12.31/MOD10A1.A2016366.h14v03.006.2017002110336.hdf.xml"
    url = "https://oceancolor.gsfc.nasa.gov/showimages/MODISA/IMAGES/CHL/L3/2023/0914/AQUA_MODIS.20230914.L3m.DAY.CHL.chlor_a.4km.NRT.nc.png"
    url = "https://oceancolor.gsfc.nasa.gov/showimages/MODISA/IMAGES/RRS/L3/2023/0925/AQUA_MODIS.20230925.L3m.DAY.RRS.Rrs_412.4km.NRT.nc.png"

    # extract the filename from the url to be used when saving the file


    import os
    if not os.path.isdir("tmp_dir"):
        os.makedirs("tmp_dir")
    filename = os.path.join("tmp_dir", url[url.rfind('/')+1:])



    try:

        # submit the request using the session

        response = session.get(url, stream=True)

        print(response.status_code)



        # raise an exception in case of http errors

        response.raise_for_status()  



        # save the file

        with open(filename, 'wb') as fd:

            for chunk in response.iter_content(chunk_size=1024*1024):

                print(chunk)

                fd.write(chunk)



    except requests.exceptions.HTTPError as e:

        # handle any errors here

        print(e)

# %%
if False:
    from usgs import api

    # Set the EarthExplorer catalog
    node = 'EE'# this indicates earth explorer website

    # Set the Hyperion and Landsat 8 dataset
    hyperion_dataset = 'EO1_HYP_PUB'
    landsat8_dataset = 'LANDSAT_8'

    # Set the scene ids
    hyperion_scene_id = 'EO1H1820422014302110K2_SG1_01'
    landsat8_scene_id = 'LC80290462015135LGN00'

    # Submit requests to USGS servers
    api.metadata(hyperion_dataset, node, [hyperion_scene_id])
    api.metadata(landsat8_dataset, node, [landsat8_scene_id])

# %%
if False:
    from usgs import api


    def submit_where_query():

        # USGS uses numerical codes to identify queryable fields
        # To see which fields are queryable for a specific dataset,
        # send off a request to dataset-fields

        results = api.dataset_fields('LANDSAT_8_C1', 'EE')

        for field in results['data']:
            print(field)

        # WRS Path happens to have the field id 20514
        where = {
            20514: '043'
        }
        results = api.search('LANDSAT_8_C1', 'EE', where=where, start_date='2017-04-01', end_date='2017-05-01', max_results=10, extended=True)

        for scene in results['data']['results']:
            print(scene)

    submit_where_query()

# %%
import json
from landsatxplore.api import API

# Initialize a new API instance and get an access key
api = API(username, password)

# Search for Landsat TM scenes
scenes = api.search(
    dataset='landsat_ot_c2_l1',
    latitude=37.47,
    longitude=-122.37,
    start_date='2013-01-01',
    end_date='2023-10-01',
    max_cloud_cover=10
)

print(f"{len(scenes)} scenes found.")

# Process the result
for scene in scenes:
    print(scene)
    print(scene['acquisition_date'].strftime('%Y-%m-%d'))
    # Write scene footprints to disk
    #fname = f"{scene['landsat_product_id']}.geojson"
    #with open(fname, "w") as f:
    #    json.dump(scene['spatial_coverage'].__geo_interface__, f)
    

api.logout()
# Out:
# 90 scenes found.
# {'cloud_cover': 0, 'entity_id': 'LC90440342023270LGN00', 'display_id': 'LC09_L1TP_044034_20230927_20230927_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20230927_20230927_02_T1', 'landsat_scene_id': 'LC90440342023270LGN00', 'acquisition_date': datetime.datetime(2023, 9, 27, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2023, 9, 27, 0, 0), 'land_cloud_cover': 0.07, 'scene_cloud_cover': 0.1, 'start_time': datetime.datetime(2023, 9, 27, 18, 45, 48), 'stop_time': datetime.datetime(2023, 9, 27, 18, 46, 19), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1118, 'ground_control_points_version': 5, 'geometric_rmse_model': 4.176, 'geometric_rmse_model_x': 2.785, 'geometric_rmse_model_y': 3.111, 'image_quality': 9, 'processing_software_version': 'LPGS_16.3.0', 'sun_elevation_l0ra': 47.25945992, 'sun_azimuth_l0ra': 152.41843132, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20230927183154_20230927192009.01', 'bias_parameter_file_name_tirs': 'LT9BPF20230927182703_20230927192100.01', 'calibration_parameter_file': 'LC09CPF_20230701_20230930_02.02', 'rlut_file_name': 'LC09RLUT_20230701_20531231_02_10.h5', 'scene_center_latitude': 37.47425, 'scene_center_longitude': -122.09711, 'corner_upper_left_latitude': 38.52549, 'corner_upper_left_longitude': -123.40497, 'corner_upper_right_latitude': 38.50488, 'corner_upper_right_longitude': -120.76598, 'corner_lower_left_latitude': 36.41904, 'corner_lower_left_longitude': -123.39376, 'corner_lower_right_latitude': 36.39993, 'corner_lower_right_longitude': -120.82775, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.39315, 36.40908, -120.78044, 38.52485), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A5B55A190>, 'temporal_coverage': [datetime.datetime(2023, 9, 27, 0, 0), datetime.datetime(2023, 9, 27, 0, 0)], 'publish_date': datetime.datetime(2023, 9, 27, 17, 53, 45, tzinfo=tzoffset(None, -18000))}
# 2023-09-27
# {'cloud_cover': 5, 'entity_id': 'LC80440342023198LGN00', 'display_id': 'LC08_L1TP_044034_20230717_20230725_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20230717_20230725_02_T1', 'landsat_scene_id': 'LC80440342023198LGN00', 'acquisition_date': datetime.datetime(2023, 7, 17, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2023, 7, 25, 0, 0), 'land_cloud_cover': 0.77, 'scene_cloud_cover': 5.34, 'start_time': datetime.datetime(2023, 7, 17, 18, 45, 31), 'stop_time': datetime.datetime(2023, 7, 17, 18, 46, 2), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1081, 'ground_control_points_version': 5, 'geometric_rmse_model': 4.729, 'geometric_rmse_model_x': 3.166, 'geometric_rmse_model_y': 3.512, 'image_quality': 9, 'processing_software_version': 'LPGS_16.3.0', 'sun_elevation_l0ra': 64.78517025, 'sun_azimuth_l0ra': 124.15002546, 'tirs_ssm_model': 'FINAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15601, 'panchromatic_samples': 15341, 'reflective_lines': 7801, 'reflective_samples': 7671, 'thermal_lines': 7801, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20230717182427_20230717200320.01', 'bias_parameter_file_name_tirs': 'LT8BPF20230712143718_20230718102313.01', 'calibration_parameter_file': 'LC08CPF_20230701_20230930_02.02', 'rlut_file_name': 'LC08RLUT_20150303_20431231_02_01.h5', 'scene_center_latitude': 37.47471, 'scene_center_longitude': -122.10377, 'corner_upper_left_latitude': 38.52817, 'corner_upper_left_longitude': -123.41187, 'corner_upper_right_latitude': 38.50771, 'corner_upper_right_longitude': -120.77277, 'corner_lower_left_latitude': 36.41902, 'corner_lower_left_longitude': -123.40045, 'corner_lower_right_latitude': 36.40005, 'corner_lower_right_longitude': -120.83444, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.39959, 36.40812, -120.78698, 38.52675), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E7EB80>, 'temporal_coverage': [datetime.datetime(2023, 7, 17, 0, 0), datetime.datetime(2023, 7, 17, 0, 0)], 'publish_date': datetime.datetime(2023, 7, 17, 18, 15, 54, tzinfo=tzoffset(None, -18000))}
# 2023-07-17
# {'cloud_cover': 3, 'entity_id': 'LC90440342023110LGN00', 'display_id': 'LC09_L1TP_044034_20230420_20230420_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20230420_20230420_02_T1', 'landsat_scene_id': 'LC90440342023110LGN00', 'acquisition_date': datetime.datetime(2023, 4, 20, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2023, 4, 20, 0, 0), 'land_cloud_cover': 0.52, 'scene_cloud_cover': 3.27, 'start_time': datetime.datetime(2023, 4, 20, 18, 45, 39), 'stop_time': datetime.datetime(2023, 4, 20, 18, 46, 11), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 895, 'ground_control_points_version': 5, 'geometric_rmse_model': 6.017, 'geometric_rmse_model_x': 4.255, 'geometric_rmse_model_y': 4.254, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 58.34069925, 'sun_azimuth_l0ra': 139.43471283, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20230420182747_20230420200728.01', 'bias_parameter_file_name_tirs': 'LT9BPF20230420182256_20230420200237.01', 'calibration_parameter_file': 'LC09CPF_20230401_20230630_02.01', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47444, 'scene_center_longitude': -122.15016, 'corner_upper_left_latitude': 38.52529, 'corner_upper_left_longitude': -123.46003, 'corner_upper_right_latitude': 38.50592, 'corner_upper_right_longitude': -120.82099, 'corner_lower_left_latitude': 36.41885, 'corner_lower_left_longitude': -123.4473, 'corner_lower_right_latitude': 36.40089, 'corner_lower_right_longitude': -120.88125, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.44555, 36.40974, -120.83398, 38.52453), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E9A430>, 'temporal_coverage': [datetime.datetime(2023, 4, 20, 0, 0), datetime.datetime(2023, 4, 20, 0, 0)], 'publish_date': datetime.datetime(2023, 4, 20, 18, 8, 19, tzinfo=tzoffset(None, -18000))}
# 2023-04-20
# {'cloud_cover': 2, 'entity_id': 'LC90440342023094LGN00', 'display_id': 'LC09_L1TP_044034_20230404_20230404_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20230404_20230404_02_T1', 'landsat_scene_id': 'LC90440342023094LGN00', 'acquisition_date': datetime.datetime(2023, 4, 4, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2023, 4, 4, 0, 0), 'land_cloud_cover': 2.67, 'scene_cloud_cover': 2.4, 'start_time': datetime.datetime(2023, 4, 4, 18, 45, 46), 'stop_time': datetime.datetime(2023, 4, 4, 18, 46, 17), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 831, 'ground_control_points_version': 5, 'geometric_rmse_model': 6.268, 'geometric_rmse_model_x': 4.425, 'geometric_rmse_model_y': 4.439, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 52.82598333, 'sun_azimuth_l0ra': 143.13165452, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20230404182953_20230404191919.01', 'bias_parameter_file_name_tirs': 'LT9BPF20230404182502_20230404192010.01', 'calibration_parameter_file': 'LC09CPF_20230401_20230630_02.01', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.4745, 'scene_center_longitude': -122.13697, 'corner_upper_left_latitude': 38.52534, 'corner_upper_left_longitude': -123.44627, 'corner_upper_right_latitude': 38.50566, 'corner_upper_right_longitude': -120.80724, 'corner_lower_left_latitude': 36.4189, 'corner_lower_left_longitude': -123.43392, 'corner_lower_right_latitude': 36.40065, 'corner_lower_right_longitude': -120.86787, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.43251, 36.40978, -120.8207, 38.52462), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E9A400>, 'temporal_coverage': [datetime.datetime(2023, 4, 4, 0, 0), datetime.datetime(2023, 4, 4, 0, 0)], 'publish_date': datetime.datetime(2023, 4, 4, 18, 29, 13, tzinfo=tzoffset(None, -18000))}
# 2023-04-04
# {'cloud_cover': 2, 'entity_id': 'LC80440342023086LGN00', 'display_id': 'LC08_L1TP_044034_20230327_20230405_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20230327_20230405_02_T1', 'landsat_scene_id': 'LC80440342023086LGN00', 'acquisition_date': datetime.datetime(2023, 3, 27, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2023, 4, 5, 0, 0), 'land_cloud_cover': 3.96, 'scene_cloud_cover': 2.49, 'start_time': datetime.datetime(2023, 3, 27, 18, 45, 38), 'stop_time': datetime.datetime(2023, 3, 27, 18, 46, 9), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 882, 'ground_control_points_version': 5, 'geometric_rmse_model': 6.687, 'geometric_rmse_model_x': 4.715, 'geometric_rmse_model_y': 4.742, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 49.80119309, 'sun_azimuth_l0ra': 144.5726897, 'tirs_ssm_model': 'FINAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20230327182406_20230327191911.01', 'bias_parameter_file_name_tirs': 'LT8BPF20230322111253_20230331104454.01', 'calibration_parameter_file': 'LC08CPF_20230101_20230331_02.03', 'rlut_file_name': 'LC08RLUT_20150303_20431231_02_01.h5', 'scene_center_latitude': 37.47461, 'scene_center_longitude': -122.13544, 'corner_upper_left_latitude': 38.52536, 'corner_upper_left_longitude': -123.44283, 'corner_upper_right_latitude': 38.5056, 'corner_upper_right_longitude': -120.8038, 'corner_lower_left_latitude': 36.41892, 'corner_lower_left_longitude': -123.43057, 'corner_lower_right_latitude': 36.40059, 'corner_lower_right_longitude': -120.86453, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.43064, 36.40863, -120.81928, 38.52606), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E9A700>, 'temporal_coverage': [datetime.datetime(2023, 3, 27, 0, 0), datetime.datetime(2023, 3, 27, 0, 0)], 'publish_date': datetime.datetime(2023, 3, 27, 16, 36, 3, tzinfo=tzoffset(None, -18000))}
# 2023-03-27
# {'cloud_cover': 0, 'entity_id': 'LC90440342023046LGN01', 'display_id': 'LC09_L1TP_044034_20230215_20230310_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20230215_20230310_02_T1', 'landsat_scene_id': 'LC90440342023046LGN01', 'acquisition_date': datetime.datetime(2023, 2, 15, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2023, 3, 10, 0, 0), 'land_cloud_cover': 0.17, 'scene_cloud_cover': 0.11, 'start_time': datetime.datetime(2023, 2, 15, 18, 46, 15), 'stop_time': datetime.datetime(2023, 2, 15, 18, 46, 47), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 979, 'ground_control_points_version': 5, 'geometric_rmse_model': 6.617, 'geometric_rmse_model_x': 4.143, 'geometric_rmse_model_y': 5.159, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 35.08558622, 'sun_azimuth_l0ra': 150.90877541, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20230215183533_20230215192236.02', 'bias_parameter_file_name_tirs': 'LT9BPF20230215183042_20230215192327.03', 'calibration_parameter_file': 'LC09CPF_20230101_20230331_02.02', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47462, 'scene_center_longitude': -122.17325, 'corner_upper_left_latitude': 38.52521, 'corner_upper_left_longitude': -123.48068, 'corner_upper_right_latitude': 38.5063, 'corner_upper_right_longitude': -120.84162, 'corner_lower_left_latitude': 36.41878, 'corner_lower_left_longitude': -123.46738, 'corner_lower_right_latitude': 36.40125, 'corner_lower_right_longitude': -120.90131, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.46877, 36.40979, -120.85697, 38.52486), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E9A850>, 'temporal_coverage': [datetime.datetime(2023, 2, 15, 0, 0), datetime.datetime(2023, 2, 15, 0, 0)], 'publish_date': datetime.datetime(2023, 3, 10, 1, 18, 43, tzinfo=tzoffset(None, -21600))}
# 2023-02-15
# {'cloud_cover': 0, 'entity_id': 'LC90440342023030LGN01', 'display_id': 'LC09_L1TP_044034_20230130_20230311_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20230130_20230311_02_T1', 'landsat_scene_id': 'LC90440342023030LGN01', 'acquisition_date': datetime.datetime(2023, 1, 30, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2023, 3, 11, 0, 0), 'land_cloud_cover': 0.09, 'scene_cloud_cover': 0.06, 'start_time': datetime.datetime(2023, 1, 30, 18, 46, 16), 'stop_time': datetime.datetime(2023, 1, 30, 18, 46, 47), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 959, 'ground_control_points_version': 5, 'geometric_rmse_model': 7.389, 'geometric_rmse_model_x': 4.325, 'geometric_rmse_model_y': 5.991, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 30.54998084, 'sun_azimuth_l0ra': 153.42773016, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20230130183708_20230130192236.01', 'bias_parameter_file_name_tirs': 'LT9BPF20230130183217_20230130192328.02', 'calibration_parameter_file': 'LC09CPF_20230101_20230331_02.02', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47437, 'scene_center_longitude': -122.15483, 'corner_upper_left_latitude': 38.52528, 'corner_upper_left_longitude': -123.46347, 'corner_upper_right_latitude': 38.50598, 'corner_upper_right_longitude': -120.82443, 'corner_lower_left_latitude': 36.41884, 'corner_lower_left_longitude': -123.45065, 'corner_lower_right_latitude': 36.40095, 'corner_lower_right_longitude': -120.88459, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.45058, 36.40947, -120.8385, 38.52467), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E9AAC0>, 'temporal_coverage': [datetime.datetime(2023, 1, 30, 0, 0), datetime.datetime(2023, 1, 30, 0, 0)], 'publish_date': datetime.datetime(2023, 3, 11, 14, 50, 58, tzinfo=tzoffset(None, -21600))}
# 2023-01-30
# {'cloud_cover': 1, 'entity_id': 'LC80440342023022LGN00', 'display_id': 'LC08_L1TP_044034_20230122_20230207_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20230122_20230207_02_T1', 'landsat_scene_id': 'LC80440342023022LGN00', 'acquisition_date': datetime.datetime(2023, 1, 22, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2023, 2, 7, 0, 0), 'land_cloud_cover': 1.43, 'scene_cloud_cover': 1.05, 'start_time': datetime.datetime(2023, 1, 22, 18, 46, 9), 'stop_time': datetime.datetime(2023, 1, 22, 18, 46, 41), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 813, 'ground_control_points_version': 5, 'geometric_rmse_model': 7.948, 'geometric_rmse_model_x': 4.764, 'geometric_rmse_model_y': 6.362, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 28.80695094, 'sun_azimuth_l0ra': 154.71343703, 'tirs_ssm_model': 'FINAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20230122165134_20230122192230.01', 'bias_parameter_file_name_tirs': 'LT8BPF20230121104904_20230128061312.01', 'calibration_parameter_file': 'LC08CPF_20230101_20230331_02.01', 'rlut_file_name': 'LC08RLUT_20150303_20431231_02_01.h5', 'scene_center_latitude': 37.47455, 'scene_center_longitude': -122.12947, 'corner_upper_left_latitude': 38.52537, 'corner_upper_left_longitude': -123.43938, 'corner_upper_right_latitude': 38.50553, 'corner_upper_right_longitude': -120.80036, 'corner_lower_left_latitude': 36.41893, 'corner_lower_left_longitude': -123.42722, 'corner_lower_right_latitude': 36.40053, 'corner_lower_right_longitude': -120.86119, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.42525, 36.40842, -120.81267, 38.52614), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E9ACD0>, 'temporal_coverage': [datetime.datetime(2023, 1, 22, 0, 0), datetime.datetime(2023, 1, 22, 0, 0)], 'publish_date': datetime.datetime(2023, 1, 22, 15, 0, 27, tzinfo=tzoffset(None, -21600))}
# 2023-01-22
# {'cloud_cover': 1, 'entity_id': 'LC90440342022347LGN01', 'display_id': 'LC09_L1TP_044034_20221213_20230318_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20221213_20230318_02_T1', 'landsat_scene_id': 'LC90440342022347LGN01', 'acquisition_date': datetime.datetime(2022, 12, 13, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2023, 3, 18, 0, 0), 'land_cloud_cover': 0.86, 'scene_cloud_cover': 0.73, 'start_time': datetime.datetime(2022, 12, 13, 18, 46, 15), 'stop_time': datetime.datetime(2022, 12, 13, 18, 46, 47), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 913, 'ground_control_points_version': 5, 'geometric_rmse_model': 7.766, 'geometric_rmse_model_x': 4.108, 'geometric_rmse_model_y': 6.59, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 26.74703369, 'sun_azimuth_l0ra': 160.35721954, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20221213183844_20221213192701.01', 'bias_parameter_file_name_tirs': 'LT9BPF20221213183353_20221213192752.02', 'calibration_parameter_file': 'LC09CPF_20221001_20221231_02.04', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47438, 'scene_center_longitude': -122.12701, 'corner_upper_left_latitude': 38.52538, 'corner_upper_left_longitude': -123.43594, 'corner_upper_right_latitude': 38.50547, 'corner_upper_right_longitude': -120.79692, 'corner_lower_left_latitude': 36.41894, 'corner_lower_left_longitude': -123.42388, 'corner_lower_right_latitude': 36.40047, 'corner_lower_right_longitude': -120.85784, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.42268, 36.40938, -120.81065, 38.5248), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69E9AE80>, 'temporal_coverage': [datetime.datetime(2022, 12, 13, 0, 0), datetime.datetime(2022, 12, 13, 0, 0)], 'publish_date': datetime.datetime(2023, 3, 17, 22, 17, 57, tzinfo=tzoffset(None, -18000))}
# 2022-12-13
# {'cloud_cover': 0, 'entity_id': 'LC80440342022323LGN00', 'display_id': 'LC08_L1TP_044034_20221119_20221128_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20221119_20221128_02_T1', 'landsat_scene_id': 'LC80440342022323LGN00', 'acquisition_date': datetime.datetime(2022, 11, 19, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2022, 11, 28, 0, 0), 'land_cloud_cover': 0.08, 'scene_cloud_cover': 0.05, 'start_time': datetime.datetime(2022, 11, 19, 18, 46, 20), 'stop_time': datetime.datetime(2022, 11, 19, 18, 46, 52), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1053, 'ground_control_points_version': 5, 'geometric_rmse_model': 6.326, 'geometric_rmse_model_x': 3.46, 'geometric_rmse_model_y': 5.296, 'image_quality': 9, 'processing_software_version': 'LPGS_16.1.0', 'sun_elevation_l0ra': 30.78597595, 'sun_azimuth_l0ra': 161.4997384, 'tirs_ssm_model': 'FINAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15601, 'panchromatic_samples': 15341, 'reflective_lines': 7801, 'reflective_samples': 7671, 'thermal_lines': 7801, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20221119165145_20221119193630.01', 'bias_parameter_file_name_tirs': 'LT8BPF20221116142552_20221123104545.04', 'calibration_parameter_file': 'LC08CPF_20221001_20221231_02.02', 'rlut_file_name': 'LC08RLUT_20150303_20431231_02_01.h5', 'scene_center_latitude': 37.47425, 'scene_center_longitude': -122.11335, 'corner_upper_left_latitude': 38.52543, 'corner_upper_left_longitude': -123.42218, 'corner_upper_right_latitude': 38.50521, 'corner_upper_right_longitude': -120.78317, 'corner_lower_left_latitude': 36.41628, 'corner_lower_left_longitude': -123.41048, 'corner_lower_right_latitude': 36.39753, 'corner_lower_right_longitude': -120.84454, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.40896, 36.40795, -120.79676, 38.52603), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BF070>, 'temporal_coverage': [datetime.datetime(2022, 11, 19, 0, 0), datetime.datetime(2022, 11, 19, 0, 0)], 'publish_date': datetime.datetime(2022, 11, 19, 18, 21, 21, tzinfo=tzoffset(None, -21600))}
# 2022-11-19
# {'cloud_cover': 0, 'entity_id': 'LC80440342022307LGN00', 'display_id': 'LC08_L1TP_044034_20221103_20221114_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20221103_20221114_02_T1', 'landsat_scene_id': 'LC80440342022307LGN00', 'acquisition_date': datetime.datetime(2022, 11, 3, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2022, 11, 14, 0, 0), 'land_cloud_cover': 0.15, 'scene_cloud_cover': 0.09, 'start_time': datetime.datetime(2022, 11, 3, 18, 46, 27), 'stop_time': datetime.datetime(2022, 11, 3, 18, 46, 59), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1058, 'ground_control_points_version': 5, 'geometric_rmse_model': 5.761, 'geometric_rmse_model_x': 3.09, 'geometric_rmse_model_y': 4.863, 'image_quality': 9, 'processing_software_version': 'LPGS_16.1.0', 'sun_elevation_l0ra': 35.09805279, 'sun_azimuth_l0ra': 160.61567644, 'tirs_ssm_model': 'FINAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15621, 'panchromatic_samples': 15341, 'reflective_lines': 7811, 'reflective_samples': 7671, 'thermal_lines': 7811, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20221103183029_20221103192248.01', 'bias_parameter_file_name_tirs': 'LT8BPF20221101150907_20221108212850.01', 'calibration_parameter_file': 'LC08CPF_20221001_20221231_02.01', 'rlut_file_name': 'LC08RLUT_20150303_20431231_02_01.h5', 'scene_center_latitude': 37.47443, 'scene_center_longitude': -122.13707, 'corner_upper_left_latitude': 38.52805, 'corner_upper_left_longitude': -123.44628, 'corner_upper_right_latitude': 38.50836, 'corner_upper_right_longitude': -120.80715, 'corner_lower_left_latitude': 36.4162, 'corner_lower_left_longitude': -123.4339, 'corner_lower_right_latitude': 36.39795, 'corner_lower_right_longitude': -120.86795, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.4328, 36.40815, -120.82024, 38.52619), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BF220>, 'temporal_coverage': [datetime.datetime(2022, 11, 3, 0, 0), datetime.datetime(2022, 11, 3, 0, 0)], 'publish_date': datetime.datetime(2022, 11, 3, 16, 48, 50, tzinfo=tzoffset(None, -18000))}
# 2022-11-03
# {'cloud_cover': 0, 'entity_id': 'LC90440342022299LGN01', 'display_id': 'LC09_L1TP_044034_20221026_20230324_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20221026_20230324_02_T1', 'landsat_scene_id': 'LC90440342022299LGN01', 'acquisition_date': datetime.datetime(2022, 10, 26, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2023, 3, 24, 0, 0), 'land_cloud_cover': 0.12, 'scene_cloud_cover': 0.08, 'start_time': datetime.datetime(2022, 10, 26, 18, 46, 15), 'stop_time': datetime.datetime(2022, 10, 26, 18, 46, 47), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1081, 'ground_control_points_version': 5, 'geometric_rmse_model': 5.103, 'geometric_rmse_model_x': 2.824, 'geometric_rmse_model_y': 4.25, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 37.56252463, 'sun_azimuth_l0ra': 159.55890985, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20221026183533_20221026192236.02', 'bias_parameter_file_name_tirs': 'LT9BPF20221026183042_20221026192327.03', 'calibration_parameter_file': 'LC09CPF_20221001_20221231_02.04', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47455, 'scene_center_longitude': -122.1294, 'corner_upper_left_latitude': 38.52537, 'corner_upper_left_longitude': -123.43938, 'corner_upper_right_latitude': 38.50553, 'corner_upper_right_longitude': -120.80036, 'corner_lower_left_latitude': 36.41893, 'corner_lower_left_longitude': -123.42722, 'corner_lower_right_latitude': 36.40053, 'corner_lower_right_longitude': -120.86119, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.42542, 36.4095, -120.8128, 38.52508), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BF3D0>, 'temporal_coverage': [datetime.datetime(2022, 10, 26, 0, 0), datetime.datetime(2022, 10, 26, 0, 0)], 'publish_date': datetime.datetime(2023, 3, 24, 1, 55, 26, tzinfo=tzoffset(None, -18000))}
# 2022-10-26
# {'cloud_cover': 5, 'entity_id': 'LC80440342022259LGN00', 'display_id': 'LC08_L1TP_044034_20220916_20220922_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20220916_20220922_02_T1', 'landsat_scene_id': 'LC80440342022259LGN00', 'acquisition_date': datetime.datetime(2022, 9, 16, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2022, 9, 22, 0, 0), 'land_cloud_cover': 0.56, 'scene_cloud_cover': 5.45, 'start_time': datetime.datetime(2022, 9, 16, 18, 46, 27), 'stop_time': datetime.datetime(2022, 9, 16, 18, 46, 58), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1092, 'ground_control_points_version': 5, 'geometric_rmse_model': 4.096, 'geometric_rmse_model_x': 2.724, 'geometric_rmse_model_y': 3.059, 'image_quality': 9, 'processing_software_version': 'LPGS_16.1.0', 'sun_elevation_l0ra': 50.78840771, 'sun_azimuth_l0ra': 148.7754238, 'tirs_ssm_model': 'FINAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15621, 'panchromatic_samples': 15341, 'reflective_lines': 7811, 'reflective_samples': 7671, 'thermal_lines': 7811, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20220916182519_20220916191912.01', 'bias_parameter_file_name_tirs': 'LT8BPF20220910204234_20220917101446.01', 'calibration_parameter_file': 'LC08CPF_20220701_20220930_02.02', 'rlut_file_name': 'LC08RLUT_20150303_20431231_02_01.h5', 'scene_center_latitude': 37.47466, 'scene_center_longitude': -122.13843, 'corner_upper_left_latitude': 38.52805, 'corner_upper_left_longitude': -123.44628, 'corner_upper_right_latitude': 38.50836, 'corner_upper_right_longitude': -120.80715, 'corner_lower_left_latitude': 36.4162, 'corner_lower_left_longitude': -123.4339, 'corner_lower_right_latitude': 36.39795, 'corner_lower_right_longitude': -120.86795, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.43405, 36.40821, -120.82168, 38.52651), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BF580>, 'temporal_coverage': [datetime.datetime(2022, 9, 16, 0, 0), datetime.datetime(2022, 9, 16, 0, 0)], 'publish_date': datetime.datetime(2022, 9, 16, 17, 21, 25, tzinfo=tzoffset(None, -18000))}
# 2022-09-16
# {'cloud_cover': 0, 'entity_id': 'LC90440342022251LGN02', 'display_id': 'LC09_L1TP_044034_20220908_20230330_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20220908_20230330_02_T1', 'landsat_scene_id': 'LC90440342022251LGN02', 'acquisition_date': datetime.datetime(2022, 9, 8, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2023, 3, 30, 0, 0), 'land_cloud_cover': 0.03, 'scene_cloud_cover': 0.03, 'start_time': datetime.datetime(2022, 9, 8, 18, 46, 1), 'stop_time': datetime.datetime(2022, 9, 8, 18, 46, 33), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1107, 'ground_control_points_version': 5, 'geometric_rmse_model': 3.771, 'geometric_rmse_model_x': 2.58, 'geometric_rmse_model_y': 2.751, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 53.20480207, 'sun_azimuth_l0ra': 145.4860639, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20220908183008_20220908191759.02', 'bias_parameter_file_name_tirs': 'LT9BPF20220908182517_20220908191850.02', 'calibration_parameter_file': 'LC09CPF_20220701_20220930_02.04', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47473, 'scene_center_longitude': -122.10853, 'corner_upper_left_latitude': 38.52546, 'corner_upper_left_longitude': -123.41529, 'corner_upper_right_latitude': 38.50508, 'corner_upper_right_longitude': -120.77629, 'corner_lower_left_latitude': 36.41901, 'corner_lower_left_longitude': -123.4038, 'corner_lower_right_latitude': 36.40011, 'corner_lower_right_longitude': -120.83778, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.40477, 36.40954, -120.79152, 38.52532), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BF730>, 'temporal_coverage': [datetime.datetime(2022, 9, 8, 0, 0), datetime.datetime(2022, 9, 8, 0, 0)], 'publish_date': datetime.datetime(2023, 3, 29, 20, 14, 15, tzinfo=tzoffset(None, -18000))}
# 2022-09-08
# {'cloud_cover': 0, 'entity_id': 'LC90440342022171LGN01', 'display_id': 'LC09_L1TP_044034_20220620_20230411_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20220620_20230411_02_T1', 'landsat_scene_id': 'LC90440342022171LGN01', 'acquisition_date': datetime.datetime(2022, 6, 20, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': -0.001, 'date_product_generated': datetime.datetime(2023, 4, 11, 0, 0), 'land_cloud_cover': 0.07, 'scene_cloud_cover': 0.24, 'start_time': datetime.datetime(2022, 6, 20, 18, 45, 34), 'stop_time': datetime.datetime(2022, 6, 20, 18, 46, 5), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1109, 'ground_control_points_version': 5, 'geometric_rmse_model': 4.268, 'geometric_rmse_model_x': 2.797, 'geometric_rmse_model_y': 3.223, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 67.12128582, 'sun_azimuth_l0ra': 121.85043091, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20220620182406_20220620190333.02', 'bias_parameter_file_name_tirs': 'LT9BPF20220620171421_20220620181915.03', 'calibration_parameter_file': 'LC09CPF_20220401_20220630_02.04', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47432, 'scene_center_longitude': -122.13846, 'corner_upper_left_latitude': 38.52534, 'corner_upper_left_longitude': -123.44627, 'corner_upper_right_latitude': 38.50566, 'corner_upper_right_longitude': -120.80724, 'corner_lower_left_latitude': 36.4189, 'corner_lower_left_longitude': -123.43392, 'corner_lower_right_latitude': 36.40065, 'corner_lower_right_longitude': -120.86787, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.43509, 36.40905, -120.82099, 38.52493), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BF8E0>, 'temporal_coverage': [datetime.datetime(2022, 6, 20, 0, 0), datetime.datetime(2022, 6, 20, 0, 0)], 'publish_date': datetime.datetime(2023, 4, 11, 3, 11, 19, tzinfo=tzoffset(None, -18000))}
# 2022-06-20
# {'cloud_cover': 2, 'entity_id': 'LC90440342022139LGN01', 'display_id': 'LC09_L1TP_044034_20220519_20230416_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC09_L1TP_044034_20220519_20230416_02_T1', 'landsat_scene_id': 'LC90440342022139LGN01', 'acquisition_date': datetime.datetime(2022, 5, 19, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.001, 'date_product_generated': datetime.datetime(2023, 4, 16, 0, 0), 'land_cloud_cover': 3.24, 'scene_cloud_cover': 2.32, 'start_time': datetime.datetime(2022, 5, 19, 18, 45, 19), 'stop_time': datetime.datetime(2022, 5, 19, 18, 45, 51), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1075, 'ground_control_points_version': 5, 'geometric_rmse_model': 4.415, 'geometric_rmse_model_x': 3.178, 'geometric_rmse_model_y': 3.065, 'image_quality': 9, 'processing_software_version': 'LPGS_16.2.0', 'sun_elevation_l0ra': 65.33635071, 'sun_azimuth_l0ra': 129.98279049, 'tirs_ssm_model': 'N/A', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 9, 'panchromatic_lines': 15581, 'panchromatic_samples': 15341, 'reflective_lines': 7791, 'reflective_samples': 7671, 'thermal_lines': 7791, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO9BPF20220519182503_20220519190318.02', 'bias_parameter_file_name_tirs': 'LT9BPF20220519182012_20220519190409.03', 'calibration_parameter_file': 'LC09CPF_20220401_20220630_02.04', 'rlut_file_name': 'LC09RLUT_20220319_20531231_02_09.h5', 'scene_center_latitude': 37.47435, 'scene_center_longitude': -122.14776, 'corner_upper_left_latitude': 38.5253, 'corner_upper_left_longitude': -123.45659, 'corner_upper_right_latitude': 38.50585, 'corner_upper_right_longitude': -120.81755, 'corner_lower_left_latitude': 36.41887, 'corner_lower_left_longitude': -123.44395, 'corner_lower_right_latitude': 36.40083, 'corner_lower_right_longitude': -120.8779, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.44305, 36.40969, -120.83199, 38.52444), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BFA90>, 'temporal_coverage': [datetime.datetime(2022, 5, 19, 0, 0), datetime.datetime(2022, 5, 19, 0, 0)], 'publish_date': datetime.datetime(2023, 4, 16, 2, 22, 36, tzinfo=tzoffset(None, -18000))}
# 2022-05-19
# {'cloud_cover': 2, 'entity_id': 'LC80440342022131LGN00', 'display_id': 'LC08_L1TP_044034_20220511_20220519_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20220511_20220519_02_T1', 'landsat_scene_id': 'LC80440342022131LGN00', 'acquisition_date': datetime.datetime(2022, 5, 11, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2022, 5, 19, 0, 0), 'land_cloud_cover': 3.0, 'scene_cloud_cover': 2.32, 'start_time': datetime.datetime(2022, 5, 11, 18, 45, 43, 143479), 'stop_time': datetime.datetime(2022, 5, 11, 18, 46, 14, 913479), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1007, 'ground_control_points_version': 5, 'geometric_rmse_model': 5.128, 'geometric_rmse_model_x': 3.775, 'geometric_rmse_model_y': 3.47, 'image_quality': 9, 'processing_software_version': 'LPGS_15.6.0', 'sun_elevation_l0ra': 63.97968404, 'sun_azimuth_l0ra': 132.98527576, 'tirs_ssm_model': 'FINAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15621, 'panchromatic_samples': 15341, 'reflective_lines': 7811, 'reflective_samples': 7671, 'thermal_lines': 7811, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20220511181950_20220511190342.01', 'bias_parameter_file_name_tirs': 'LT8BPF20220508142439_20220516030919.01', 'calibration_parameter_file': 'LC08CPF_20220401_20220630_02.02', 'rlut_file_name': 'LC08RLUT_20150303_20431231_02_01.h5', 'scene_center_latitude': 37.47425, 'scene_center_longitude': -122.12041, 'corner_upper_left_latitude': 38.52811, 'corner_upper_left_longitude': -123.42908, 'corner_upper_right_latitude': 38.50804, 'corner_upper_right_longitude': -120.78996, 'corner_lower_left_latitude': 36.41626, 'corner_lower_left_longitude': -123.41717, 'corner_lower_right_latitude': 36.39765, 'corner_lower_right_longitude': -120.85123, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.41642, 36.40772, -120.80339, 38.52628), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A6A5BFC40>, 'temporal_coverage': [datetime.datetime(2022, 5, 11, 0, 0), datetime.datetime(2022, 5, 11, 0, 0)], 'publish_date': datetime.datetime(2022, 6, 22, 18, 27, 47, tzinfo=tzoffset(None, -18000))}
# 2022-05-11
# ...
# 2013-12-12
# {'cloud_cover': 0, 'entity_id': 'LC80440342013266LGN01', 'display_id': 'LC08_L1TP_044034_20130923_20200912_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20130923_20200912_02_T1', 'landsat_scene_id': 'LC80440342013266LGN01', 'acquisition_date': datetime.datetime(2013, 9, 23, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2020, 9, 12, 0, 0), 'land_cloud_cover': 0.05, 'scene_cloud_cover': 0.04, 'start_time': datetime.datetime(2013, 9, 23, 18, 47, 42, 716298), 'stop_time': datetime.datetime(2013, 9, 23, 18, 48, 14, 486294), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1178, 'ground_control_points_version': 5, 'geometric_rmse_model': 2.434, 'geometric_rmse_model_x': 1.328, 'geometric_rmse_model_y': 2.041, 'image_quality': 9, 'processing_software_version': 'LPGS_15.3.1c', 'sun_elevation_l0ra': 48.61258467, 'sun_azimuth_l0ra': 151.87087908, 'tirs_ssm_model': 'ACTUAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15601, 'panchromatic_samples': 15341, 'reflective_lines': 7801, 'reflective_samples': 7671, 'thermal_lines': 7801, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20130923183303_20130923185006.02', 'bias_parameter_file_name_tirs': 'LT8BPF20130923182909_20130923185059.02', 'calibration_parameter_file': 'LC08CPF_20130920_20130930_02.01', 'rlut_file_name': 'LC08RLUT_20130211_20150302_02_01.h5', 'scene_center_latitude': 37.47435, 'scene_center_longitude': -122.10987, 'corner_upper_left_latitude': 38.52545, 'corner_upper_left_longitude': -123.41873, 'corner_upper_right_latitude': 38.50514, 'corner_upper_right_longitude': -120.77973, 'corner_lower_left_latitude': 36.41629, 'corner_lower_left_longitude': -123.40713, 'corner_lower_right_latitude': 36.39747, 'corner_lower_right_longitude': -120.8412, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.40571, 36.40815, -120.79296, 38.52598), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69F5A310>, 'temporal_coverage': [datetime.datetime(2013, 9, 23, 0, 0), datetime.datetime(2013, 9, 23, 0, 0)], 'publish_date': datetime.datetime(2022, 6, 22, 18, 27, 47, tzinfo=tzoffset(None, -18000))}
# 2013-09-23
# {'cloud_cover': 2, 'entity_id': 'LC80440342013250LGN01', 'display_id': 'LC08_L1TP_044034_20130907_20200912_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20130907_20200912_02_T1', 'landsat_scene_id': 'LC80440342013250LGN01', 'acquisition_date': datetime.datetime(2013, 9, 7, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2020, 9, 12, 0, 0), 'land_cloud_cover': 0.05, 'scene_cloud_cover': 1.61, 'start_time': datetime.datetime(2013, 9, 7, 18, 47, 50, 164882), 'stop_time': datetime.datetime(2013, 9, 7, 18, 48, 21, 934878), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1178, 'ground_control_points_version': 5, 'geometric_rmse_model': 2.537, 'geometric_rmse_model_x': 1.708, 'geometric_rmse_model_y': 1.876, 'image_quality': 9, 'processing_software_version': 'LPGS_15.3.1c', 'sun_elevation_l0ra': 53.64477208, 'sun_azimuth_l0ra': 145.80334392, 'tirs_ssm_model': 'ACTUAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 15601, 'panchromatic_samples': 15341, 'reflective_lines': 7801, 'reflective_samples': 7671, 'thermal_lines': 7801, 'thermal_samples': 7671, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20130907183311_20130907185013.02', 'bias_parameter_file_name_tirs': 'LT8BPF20130907182917_20130907185106.02', 'calibration_parameter_file': 'LC08CPF_20130701_20130919_02.01', 'rlut_file_name': 'LC08RLUT_20130211_20150302_02_01.h5', 'scene_center_latitude': 37.47471, 'scene_center_longitude': -122.12849, 'corner_upper_left_latitude': 38.52809, 'corner_upper_left_longitude': -123.43596, 'corner_upper_right_latitude': 38.50817, 'corner_upper_right_longitude': -120.79684, 'corner_lower_left_latitude': 36.41894, 'corner_lower_left_longitude': -123.42388, 'corner_lower_right_latitude': 36.40047, 'corner_lower_right_longitude': -120.85784, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.42466, 36.4085, -120.81122, 38.52638), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69F5A4C0>, 'temporal_coverage': [datetime.datetime(2013, 9, 7, 0, 0), datetime.datetime(2013, 9, 7, 0, 0)], 'publish_date': datetime.datetime(2022, 6, 22, 18, 27, 47, tzinfo=tzoffset(None, -18000))}
# 2013-09-07
# {'cloud_cover': 0, 'entity_id': 'LC80440342013170LGN01', 'display_id': 'LC08_L1TP_044034_20130619_20200912_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20130619_20200912_02_T1', 'landsat_scene_id': 'LC80440342013170LGN01', 'acquisition_date': datetime.datetime(2013, 6, 19, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2020, 9, 12, 0, 0), 'land_cloud_cover': 0.56, 'scene_cloud_cover': 0.41, 'start_time': datetime.datetime(2013, 6, 19, 18, 47, 45, 558890), 'stop_time': datetime.datetime(2013, 6, 19, 18, 48, 15, 354910), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 1080, 'ground_control_points_version': 5, 'geometric_rmse_model': 3.181, 'geometric_rmse_model_x': 2.07, 'geometric_rmse_model_y': 2.415, 'image_quality': 9, 'processing_software_version': 'LPGS_15.3.1c', 'sun_elevation_l0ra': 67.54383379, 'sun_azimuth_l0ra': 122.90434771, 'tirs_ssm_model': 'ACTUAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 14741, 'panchromatic_samples': 15141, 'reflective_lines': 7371, 'reflective_samples': 7571, 'thermal_lines': 7371, 'thermal_samples': 7571, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20130619183555_20130619185006.02', 'bias_parameter_file_name_tirs': 'LT8BPF20130619183202_20130619185058.03', 'calibration_parameter_file': 'LC08CPF_20130401_20130627_02.01', 'rlut_file_name': 'LC08RLUT_20130211_20150302_02_01.h5', 'scene_center_latitude': 37.47444, 'scene_center_longitude': -122.10103, 'corner_upper_left_latitude': 38.46877, 'corner_upper_left_longitude': -123.3909, 'corner_upper_right_latitude': 38.44854, 'corner_upper_right_longitude': -120.78834, 'corner_lower_left_latitude': 36.47588, 'corner_lower_left_longitude': -123.38065, 'corner_lower_right_latitude': 36.45705, 'corner_lower_right_longitude': -120.84625, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.37972, 36.4671, -120.8035, 38.46714), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69F5A670>, 'temporal_coverage': [datetime.datetime(2013, 6, 19, 0, 0), datetime.datetime(2013, 6, 19, 0, 0)], 'publish_date': datetime.datetime(2022, 6, 22, 18, 27, 47, tzinfo=tzoffset(None, -18000))}
# 2013-06-19
# {'cloud_cover': 0, 'entity_id': 'LC80440342013106LGN03', 'display_id': 'LC08_L1TP_044034_20130416_20200912_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20130416_20200912_02_T1', 'landsat_scene_id': 'LC80440342013106LGN03', 'acquisition_date': datetime.datetime(2013, 4, 16, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2020, 9, 12, 0, 0), 'land_cloud_cover': 0.08, 'scene_cloud_cover': 0.06, 'start_time': datetime.datetime(2013, 4, 16, 18, 47, 38, 660489), 'stop_time': datetime.datetime(2013, 4, 16, 18, 48, 8, 456509), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 966, 'ground_control_points_version': 5, 'geometric_rmse_model': 4.862, 'geometric_rmse_model_x': 3.305, 'geometric_rmse_model_y': 3.566, 'image_quality': 9, 'processing_software_version': 'LPGS_15.3.1c', 'sun_elevation_l0ra': 57.44774796, 'sun_azimuth_l0ra': 141.17711103, 'tirs_ssm_model': 'ACTUAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 14741, 'panchromatic_samples': 15141, 'reflective_lines': 7371, 'reflective_samples': 7571, 'thermal_lines': 7371, 'thermal_samples': 7571, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20130416183813_20130416184936.02', 'bias_parameter_file_name_tirs': 'LT8BPF20130416183419_20130416185028.02', 'calibration_parameter_file': 'LC08CPF_20130401_20130627_02.01', 'rlut_file_name': 'LC08RLUT_20130211_20150302_02_01.h5', 'scene_center_latitude': 37.47433, 'scene_center_longitude': -122.1102, 'corner_upper_left_latitude': 38.46873, 'corner_upper_left_longitude': -123.40121, 'corner_upper_right_latitude': 38.44873, 'corner_upper_right_longitude': -120.79865, 'corner_lower_left_latitude': 36.47585, 'corner_lower_left_longitude': -123.3907, 'corner_lower_right_latitude': 36.45723, 'corner_lower_right_longitude': -120.85628, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.38939, 36.46698, -120.81216, 38.46703), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69F5A820>, 'temporal_coverage': [datetime.datetime(2013, 4, 16, 0, 0), datetime.datetime(2013, 4, 16, 0, 0)], 'publish_date': datetime.datetime(2022, 6, 22, 18, 27, 47, tzinfo=tzoffset(None, -18000))}
# 2013-04-16
# {'cloud_cover': 0, 'entity_id': 'LC80440342013099LGN03', 'display_id': 'LC08_L1TP_044034_20130409_20200912_02_T1', 'ordering_id': 'None', 'landsat_product_id': 'LC08_L1TP_044034_20130409_20200912_02_T1', 'landsat_scene_id': 'LC80440342013099LGN03', 'acquisition_date': datetime.datetime(2013, 4, 9, 0, 0), 'collection_category': datetime.datetime(2023, 10, 1, 0, 0), 'collection_number': 2, 'wrs_path': 44, 'wrs_row': 34, 'nadir-off_nadir': 'NADIR', 'roll_angle': 0.0, 'date_product_generated': datetime.datetime(2020, 9, 12, 0, 0), 'land_cloud_cover': 0.06, 'scene_cloud_cover': 0.05, 'start_time': datetime.datetime(2013, 4, 9, 18, 46, 19, 855661), 'stop_time': datetime.datetime(2013, 4, 9, 18, 46, 49, 651682), 'station_id': 'LGN', 'day-night_indicator': 'DAY', 'ground_control_points_model': 916, 'ground_control_points_version': 5, 'geometric_rmse_model': 5.391, 'geometric_rmse_model_x': 3.678, 'geometric_rmse_model_y': 3.941, 'image_quality': 9, 'processing_software_version': 'LPGS_15.3.1c', 'sun_elevation_l0ra': 55.02650291, 'sun_azimuth_l0ra': 142.74250145, 'tirs_ssm_model': 'ACTUAL', 'data_type': 'OLI_TIRS_L1TP', 'sensor_id': 'OLI_TIRS', 'satellite': 8, 'panchromatic_lines': 14701, 'panchromatic_samples': 15021, 'reflective_lines': 7351, 'reflective_samples': 7511, 'thermal_lines': 7351, 'thermal_samples': 7511, 'product_map_projection': 'UTM', 'utm_zone': 10, 'datum': 'WGS84', 'ellipsoid': 'WGS84', 'grid_cell_size_panchromatic': 15.0, 'grid_cell_size_reflective': 30.0, 'grid_cell_size_thermal': 30.0, 'bias_parameter_file_name_oli': 'LO8BPF20130409183627_20130409184813.02', 'bias_parameter_file_name_tirs': 'LT8BPF20130409183233_20130409184905.02', 'calibration_parameter_file': 'LC08CPF_20130401_20130627_02.01', 'rlut_file_name': 'LC08RLUT_20130211_20150302_02_01.h5', 'scene_center_latitude': 37.47453, 'scene_center_longitude': -121.79184, 'corner_upper_left_latitude': 38.4694, 'corner_upper_left_longitude': -123.06763, 'corner_upper_right_latitude': 38.44244, 'corner_upper_right_longitude': -120.48607, 'corner_lower_left_latitude': 36.48188, 'corner_lower_left_longitude': -123.06587, 'corner_lower_right_latitude': 36.45678, 'corner_lower_right_longitude': -120.5517, 'has_customized_metadata': None, 'options': {'bulk': True, 'download': True, 'order': False, 'secondary': False}, 'selected': {'bulk': False, 'compare': False, 'order': False}, 'spatial_bounds': (-123.06361, 36.46695, -120.50149, 38.46769), 'spatial_coverage': <shapely.geometry.polygon.Polygon object at 0x0000024A69F5A9D0>, 'temporal_coverage': [datetime.datetime(2013, 4, 9, 0, 0), datetime.datetime(2013, 4, 9, 0, 0)], 'publish_date': datetime.datetime(2022, 6, 22, 18, 27, 47, tzinfo=tzoffset(None, -18000))}
# 2013-04-09

# %%
from landsatxplore.earthexplorer import EarthExplorer
import tarfile
import os

ee = EarthExplorer(username, password)

# "tmp_dir/LC08_L1TP_119034_20130320_20200913_02_T1.tar"

# scene["landsat_scene_id"]
for scene in scenes:
    try:
        print(scene["landsat_scene_id"])
        ee.download(scene["landsat_scene_id"], output_dir=output_dir)
        
        tar = tarfile.open(os.path.join(output_dir, scene["display_id"] + ".tar"))
        tar.extractall(path=os.path.join(output_dir, scene["display_id"]))
        tar.close()

    except Exception as E:
        print(E)

ee.logout()
# Out:
# LC90440342023270LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342023198LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342023110LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342023094LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342023086LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342023046LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342023030LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342023022LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022347LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022323LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022307LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022299LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022259LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022251LGN02
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022171LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022139LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022131LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022123LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022115LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022107LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022099LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022091LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LO90440342022075LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022067LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022059LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342022035LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022027LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342022011LGN03
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC90440342021344LGN02
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021288LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021272LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021240LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021160LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021128LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021080LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021064LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342021048LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342020334LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342020302LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342020286LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342020158LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342020094LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342020062LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342019299LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342019283LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342019267LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342019251LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342019187LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342019123LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342019075LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342018312LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342018280LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342018152LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342018104LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342018088LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342018056LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342018040LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017341LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017309LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017277LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017245LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017197LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017165LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017133LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017117LGN00
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342017005LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342016355LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342016323LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342016307LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342016275LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342016243LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342015320LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342015304LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342015224LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342015208LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342015176LGN03
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342015064LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342014365LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342014301LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342014285LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342014205LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342014077LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342014013LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342013362LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342013346LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342013266LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342013250LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342013170LGN01
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342013106LGN03
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'
# LC80440342013099LGN03
# [WinError 3] Das System kann den angegebenen Pfad nicht finden: 'E:/'

# %%
import tarfile
import os
output_dir = 'E:/Christina/land/tmp_dir/'
tar = tarfile.open(os.path.join(output_dir, 'LC08_L1TP_044034_20221119_20221128_02_T1' + ".tar"))
tar.extractall(path=os.path.join(output_dir, 'LC08_L1TP_044034_20221119_20221128_02_T1'))
tar.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21832\4066254625.py in <cell line: 4>()
#       2 import os
#       3 output_dir = 'E:/Christina/land/tmp_dir/'
# ----> 4 tar = tarfile.open(os.path.join(output_dir, 'LC08_L1TP_044034_20221119_20221128_02_T1' + ".tar"))
#       5 tar.extractall(path=os.path.join(output_dir, 'LC08_L1TP_044034_20221119_20221128_02_T1'))
#       6 tar.close()
#
# ~\anaconda3\envs\feta\lib\tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1609                     saved_pos = fileobj.tell()
#    1610                 try:
# -> 1611                     return func(name, "r", fileobj, **kwargs)
#    1612                 except (ReadError, CompressionError):
#    1613                     if fileobj is not None:
#
# ~\anaconda3\envs\feta\lib\tarfile.py in gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1673
#    1674         try:
# -> 1675             fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1676         except OSError:
#    1677             if fileobj is not None and mode == 'r':
#
# ~\anaconda3\envs\feta\lib\gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171             mode += 'b'
#     172         if fileobj is None:
# --> 173             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     174         if filename is None:
#     175             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Christina/land/tmp_dir/LC08_L1TP_044034_20221119_20221128_02_T1.tar'

# %%
from skimage import io
io.use_plugin('pil')
import matplotlib.pyplot as plt
train_data_path = r"E:\Christina\land\tmp_dir\LC08_L1TP_044034_20221119_20221128_02_T1"
import numpy as np

import cv2

stacked_image = None

images = os.listdir(train_data_path)

for image_name in images:
    
    print(image_name)
    
    if "B2" in image_name:
        print("b")
        img_path = os.path.join(train_data_path, image_name) 
        b = io.imread(img_path, plugin='tifffile')
        print(b.max())
        b = np.float64(b)
        
    if "B3" in image_name:
        print("g")
        img_path = os.path.join(train_data_path, image_name) 
        g = io.imread(img_path, plugin='tifffile')
        print(g.max())
        g = np.float64(g)
        

    if "B3" in image_name:
        print("r")
        img_path = os.path.join(train_data_path, image_name) 
        r = io.imread(img_path, plugin='tifffile')
        print(r.max())
        r = np.float64(r)
        
        
        
b *= (1.0/(65536/5) )
g *= (1.0/(65536/5) )
r *= (1.0/(65536/5) )   

b = np.clip(b, a_min = 0, a_max = 1) 
g = np.clip(g, a_min = 0, a_max = 1) 
r = np.clip(r, a_min = 0, a_max = 1) 


print(np.unique(b))
print(np.unique(g))
print(np.unique(r))

rgb = np.dstack((r,g,b))







plt.imshow(rgb)

# %%
from PIL import Image

rgb = cv2.normalize(rgb, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F).astype(np.uint8)
im = Image.fromarray(rgb)
im.save(os.path.join(train_data_path, "your_file.jpeg"))

# %%
65536/3
